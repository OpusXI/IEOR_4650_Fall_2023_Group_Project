# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data2018=pd.read_csv("england-premier-league-teams-2017-to-2018-stats.csv")
data2019=pd.read_csv("england-premier-league-teams-2018-to-2019-stats.csv")
data2020=pd.read_csv("england-premier-league-teams-2019-to-2020-stats.csv")
data2021=pd.read_csv("england-premier-league-teams-2020-to-2021-stats.csv")
data2022=pd.read_csv("england-premier-league-teams-2021-to-2022-stats.csv")

# %%
data=pd.concat([data2018,data2019,data2020,data2021,data2022])
data["points"]=3*data["wins"]+1*data["draws"]
print(data.columns)
# Out:
# Index(['team_name', 'common_name', 'season', 'country', 'matches_played',
#        'matches_played_home', 'matches_played_away', 'suspended_matches',
#        'wins', 'wins_home',
#        ...
#        'goals_conceded_min_71_to_80', 'goals_conceded_min_81_to_90',
#        'draw_percentage_overall', 'draw_percentage_home',
#        'draw_percentage_away', 'loss_percentage_ovearll',
#        'loss_percentage_home', 'loss_percentage_away',
#        'over145_corners_percentage', 'points'],
#       dtype='object', length=294)

# %%
top_4 = data[data["league_position"]<=4]
non_top_4 = data[data["league_position"]>4]
top_4
# Out:
#                team_name        common_name     season  country  \
# 1   Tottenham Hotspur FC  Tottenham Hotspur  2017/2018  England
# 2     Manchester City FC    Manchester City  2017/2018  England
# 11  Manchester United FC  Manchester United  2017/2018  England
# 12          Liverpool FC          Liverpool  2017/2018  England
# 1   Tottenham Hotspur FC  Tottenham Hotspur  2018/2019  England
# 2     Manchester City FC    Manchester City  2018/2019  England
# 10          Liverpool FC          Liverpool  2018/2019  England
# 11            Chelsea FC            Chelsea  2018/2019  England
# 2     Manchester City FC    Manchester City  2019/2020  England
# 9   Manchester United FC  Manchester United  2019/2020  England
# 10          Liverpool FC          Liverpool  2019/2020  England
# 11            Chelsea FC            Chelsea  2019/2020  England
# 2     Manchester City FC    Manchester City  2020/2021  England
# 9   Manchester United FC  Manchester United  2020/2021  England
# 10          Liverpool FC          Liverpool  2020/2021  England
# 11            Chelsea FC            Chelsea  2020/2021  England
# 1   Tottenham Hotspur FC  Tottenham Hotspur  2021/2022  England
# 2     Manchester City FC    Manchester City  2021/2022  England
# 9           Liverpool FC          Liverpool  2021/2022  England
# 10            Chelsea FC            Chelsea  2021/2022  England
#
#     matches_played  matches_played_home  matches_played_away  \
# 1               38                   19                   19
# 2               38                   19                   19
# 11              38                   19                   19
# 12              38                   19                   19
# 1               38                   19                   19
# 2               38                   19                   19
# 10              38                   19                   19
# 11              38                   19                   19
# 2               38                   19                   19
# 9               38                   19                   19
# 10              38                   19                   19
# 11              38                   19                   19
# 2               38                   19                   19
# 9               38                   19                   19
# 10              38                   19                   19
# 11              38                   19                   19
# 1               38                   19                   19
# 2               38                   19                   19
# 9               38                   19                   19
# 10              38                   19                   19
#
#     suspended_matches  wins  wins_home  ...  goals_conceded_min_71_to_80  \
# 1                   0    23         13  ...                            4
# 2                   0    32         16  ...                            1
# 11                  0    25         15  ...                            3
# 12                  0    21         12  ...                            4
# 1                   0    23         12  ...                            8
# 2                   0    32         18  ...                            2
# 10                  0    30         17  ...                            3
# 11                  0    21         12  ...                            4
# 2                   0    26         15  ...                            4
# 9                   0    18         10  ...                            1
# 10                  0    32         18  ...                            6
# 11                  0    20         11  ...                            4
# 2                   0    27         13  ...                            4
# 9                   0    21          9  ...                            5
# 10                  0    20         10  ...                            4
# 11                  0    19          9  ...                            1
# 1                   0    22         13  ...                            6
# 2                   0    29         15  ...                            2
# 9                   0    28         15  ...                            2
# 10                  0    21          9  ...                            3
#
#     goals_conceded_min_81_to_90  draw_percentage_overall  \
# 1                             8                       21
# 2                             4                       11
# 11                            2                       16
# 12                            8                       32
# 1                            10                        5
# 2                             3                        5
# 10                            4                       18
# 11                            3                       24
# 2                             9                        8
# 9                             8                       32
# 10                            3                        8
# 11                           13                       16
# 2                             4                       13
# 9                             6                       29
# 10                           11                       24
# 11                            3                       26
# 1                            10                       13
# 2                             4                       16
# 9                             2                       21
# 10                            7                       29
#
#     draw_percentage_home  draw_percentage_away  loss_percentage_ovearll  \
# 1                     21                    21                       18
# 2                     11                    11                        5
# 11                    11                    21                       18
# 12                    37                    26                       13
# 1                     11                     0                       34
# 2                      0                    11                       11
# 10                    11                    26                        3
# 11                    32                    16                       21
# 2                     11                     5                       24
# 9                     37                    26                       21
# 10                     5                    11                        8
# 11                    16                    16                       32
# 2                     11                    16                       16
# 9                     21                    37                       16
# 10                    16                    32                       24
# 11                    32                    21                       24
# 1                      5                    21                       29
# 2                     11                    21                        8
# 9                     21                    21                        5
# 10                    37                    21                       16
#
#     loss_percentage_home  loss_percentage_away  over145_corners_percentage  \
# 1                     11                    26                          13
# 2                      5                     5                           8
# 11                    11                    26                           8
# 12                     0                    26                           5
# 1                     26                    42                          11
# 2                      5                    16                           5
# 10                     0                     5                           5
# 11                     5                    37                           3
# 2                     11                    37                          24
# 9                     11                    32                          18
# 10                     0                    16                          21
# 11                    26                    37                          11
# 2                     21                    11                           8
# 9                     32                     0                           8
# 10                    32                    16                          11
# 11                    21                    26                          11
# 1                     26                    32                          11
# 2                     11                     5                          16
# 9                      0                    11                           8
# 10                    16                    16                          24
#
#     points
# 1       77
# 2      100
# 11      81
# 12      75
# 1       71
# 2       98
# 10      97
# 11      72
# 2       81
# 9       66
# 10      99
# 11      66
# 2       86
# 9       74
# 10      69
# 11      67
# 1       71
# 2       93
# 9       92
# 10      74
#
# [20 rows x 294 columns]

# %%
plt.scatter(non_top_4['points'],non_top_4["league_position"], label=f'non-top4')
plt.scatter(top_4['points'], top_4["league_position"], label=f'top4')
plt.rcParams.update({'figure.figsize':(6.4,4.8), 'figure.dpi':100})
plt.title('Top 4 and Points')
plt.legend()
plt.show()

# %% [markdown]
# The problem of interest can be formulated as a classification problems where it is predicted that a team will finish top 4 (positives) if they reach at least a certain threshold of points. It is clear from the graph that a good threshold should be a little less than 70 points, we can build a contingency table that serves as a confusion matrix to evaluate each value.

# %%
data['Top4']= ['not_Top4' if i>4 else 'Top4' for i in data['league_position']]
data['67pts']= ['O67' if i>=67 else 'U67' for i in data['points']]

# %% [markdown]
# False positives occur when the team scored over 67 points ("O67") but did not qualify for the Champions League ("Not Top4"), while false negatives are the cases where the team scored under 67 points ("U67") but still ranked top 4.

# %%
data_crosstab = pd.crosstab(data['Top4'],data['67pts'],rownames=['Actual'], colnames=['Predicted'])
data_crosstab
# Out:
# Predicted  O67  U67
# Actual
# Top4        18    2
# not_Top4     3   77

# %% [markdown]
# The Thresholds of 66 and 67 points both return an accuracy of 95%, but the threshold of 67 was chosen because it had more balance between false negatives and false positives: the confusion matrix indicates a false positive rate of 3.75% and a true positive rate of 90%.

# %%
data_def=pd.read_csv("avgDefStats.csv")
data_def
# Out:
#                  Name  Win rate  Loss rate                     Team  \
# 0         Lloyd Kelly  0.333333   0.541667              Bournemouth
# 1        Chris Mepham  0.229167   0.562500              Bournemouth
# 2          Adam Smith  0.310345   0.459770              Bournemouth
# 3         Jack Stacey  0.214286   0.571429              Bournemouth
# 4       Jordan Zemura  0.210526   0.473684              Bournemouth
# ..                ...       ...        ...                      ...
# 177              Toti  0.500000   0.285714  Wolverhampton Wanderers
# 178    Nathan Collins  0.250000   0.500000  Wolverhampton Wanderers
# 179        Hugo Bueno  0.294118   0.470588  Wolverhampton Wanderers
# 180  Dexter Lembikisa  0.000000   1.000000  Wolverhampton Wanderers
# 181      Craig Dawson  0.319066   0.424125  Wolverhampton Wanderers
#
#      Games Played  Average Tackles  Average Errors leading to a goal  \
# 0              24         1.125000                          0.041667
# 1              48         1.312500                          0.041667
# 2             174         1.959770                          0.005747
# 3              28         0.928571                          0.000000
# 4              19         2.052632                          0.000000
# ..            ...              ...                               ...
# 177            14         1.428571                          0.000000
# 178            40         1.550000                          0.000000
# 179            17         1.647059                          0.000000
# 180             1         0.000000                          0.000000
# 181           257         1.252918                          0.003891
#
#      Average Blocked shots  Average Interceptions  Average Clearances  \
# 0                 0.125000               1.083333            3.375000
# 1                 0.041667               1.208333            5.187500
# 2                 0.120690               1.178161            1.948276
# 3                 0.000000               0.821429            2.357143
# 4                 0.052632               0.842105            1.368421
# ..                     ...                    ...                 ...
# 177               0.071429               1.142857            3.357143
# 178               0.100000               1.125000            3.800000
# 179               0.117647               0.529412            1.470588
# 180               0.000000               0.000000            0.000000
# 181               0.167315               1.579767            4.447471
#
#      Average Recoveries  Average Duels won  Average Duels lost  Average Goals  \
# 0              4.708333           3.083333            2.583333       0.000000
# 1              3.583333           4.020833            2.708333       0.020833
# 2              4.091954           5.275862            4.413793       0.028736
# 3              3.678571           3.107143            2.857143       0.000000
# 4              4.105263           4.105263            4.105263       0.000000
# ..                  ...                ...                 ...            ...
# 177            3.571429           4.357143            2.642857       0.000000
# 178            5.375000           4.475000            2.975000       0.050000
# 179            4.470588           3.117647            2.941176       0.000000
# 180            2.000000           0.000000            1.000000       0.000000
# 181            4.073930           5.120623            3.638132       0.077821
#
#      Average Passes  Average Accurate long balls  Average Yellow cards  \
# 0         37.500000                     2.250000              0.208333
# 1         36.416667                     1.562500              0.187500
# 2         33.390805                     1.195402              0.218391
# 3         24.785714                     1.071429              0.142857
# 4         24.052632                     0.578947              0.052632
# ..              ...                          ...                   ...
# 177       37.000000                     1.285714              0.285714
# 178       40.775000                     2.675000              0.100000
# 179       24.352941                     0.176471              0.058824
# 180       11.000000                     0.000000              0.000000
# 181       32.758755                     2.505837              0.167315
#
#      Average Red cards  Average Fouls
# 0             0.000000       0.708333
# 1             0.000000       0.687500
# 2             0.005747       0.988506
# 3             0.000000       0.500000
# 4             0.000000       0.894737
# ..                 ...            ...
# 177           0.000000       0.571429
# 178           0.050000       0.850000
# 179           0.000000       0.294118
# 180           0.000000       0.000000
# 181           0.007782       0.972763
#
# [182 rows x 19 columns]

# %%
def build_data(data):
    data = data[data["Games Played"] >= (data["Games Played"].mean()) / 4]
    data = data.copy()
    data.loc[:, "avg_points"] = 38 * (3 * data["Win rate"] + (1 - data["Win rate"] - data["Loss rate"]))
    data["pred_top4"] = [1 if i >= 67 else 0 for i in data["avg_points"]]
    return data

# %%
def get_correlation(df):
    corr_matrix = df.corr(numeric_only=True)
    corr_points = corr_matrix.loc["avg_points"]
    corr_top4 = corr_matrix.loc["pred_top4"]
    df_corr = pd.concat([corr_points, corr_top4], axis=1)
    df_corr.columns = ["Correlation with Points Gained", "Correlation with Predicted Top 4"]
    return df_corr

# %%
data_def=pd.read_csv("avgDefStats.csv")
data_def_clean=build_data(data_def)
corr_def=get_correlation(data_def_clean)
corr_matrix_def=data_def_clean.corr(numeric_only=True)
sns.heatmap(corr_matrix_mid, annot=True, cmap='coolwarm', fmt='.1f')
print(corr_def)
# Out:
#                                   Correlation with Points Gained  \
# Win rate                                                0.988746
# Loss rate                                              -0.943642
# Games Played                                            0.186694
# Average Tackles                                        -0.113456
# Average Errors leading to a goal                        0.076240
# Average Blocked shots                                   0.173947
# Average Interceptions                                  -0.151799
# Average Clearances                                     -0.156897
# Average Recoveries                                      0.130002
# Average Duels won                                      -0.072917
# Average Duels lost                                     -0.148908
# Average Goals                                           0.121141
# Average Passes                                          0.555579
# Average Accurate long balls                             0.201333
# Average Yellow cards                                   -0.272878
# Average Red cards                                      -0.080197
# Average Fouls                                          -0.113741
# avg_points                                              1.000000
# pred_top4                                               0.776880
#
#                                   Correlation with Predicted Top 4
# Win rate                                                  0.779256
# Loss rate                                                -0.708499
# Games Played                                              0.063449
# Average Tackles                                          -0.154674
# Average Errors leading to a goal                         -0.001510
# Average Blocked shots                                     0.063678
# Average Interceptions                                    -0.200942
# Average Clearances                                       -0.074389
# Average Recoveries                                        0.024171
# Average Duels won                                        -0.211041
# Average Duels lost                                       -0.267761
# Average Goals                                             0.023441
# Average Passes                                            0.443931
# Average Accurate long balls                               0.194179
# Average Yellow cards                                     -0.204288
# Average Red cards                                        -0.088439
# Average Fouls                                            -0.188779
# avg_points                                                0.776880
# pred_top4                                                 1.000000

# %%
data_mid=pd.read_csv("avgMidStats.csv")
data_mid_clean=build_data(data_mid)
corr_mid=get_correlation(data_mid_clean)
corr_matrix_mid=data_mid_clean.corr(numeric_only=True)
sns.heatmap(corr_matrix_mid, annot=True, cmap='coolwarm', fmt='.1f')
# Out:
# <AxesSubplot:>

# %%
data_fwd=pd.read_csv("avgFwdStats.csv")
data_fwd_clean=build_data(data_fwd)
corr_fwd=get_correlation(data_fwd_clean)
corr_matrix_fwd=data_fwd_clean.corr(numeric_only=True)
sns.heatmap(corr_matrix_mid, annot=True, cmap='coolwarm', fmt='.1f')
corr_fwd
# Out:
#                              Correlation with Points Gained  \
# Win rate                                           0.991788
# Loss rate                                         -0.955786
# Games Played                                       0.323749
# Average Goals                                      0.500640
# Average Headed goals                               0.213492
# Average Penalties scored                           0.275135
# Average Freekicks scored                          -0.007598
# Average Assists                                    0.454639
# Average Shots                                      0.417633
# Average Shots on target                            0.466356
# Average Hit woodworks                              0.352466
# Average Big chances missed                         0.426898
# Average Passes                                     0.410058
# Average Big chances created                        0.449821
# Average Yellow cards                              -0.194366
# Average Red cards                                  0.029710
# Average Fouls                                     -0.115242
# Average Offsides                                   0.059221
# avg_points                                         1.000000
# pred_top4                                          0.777468
#
#                              Correlation with Predicted Top 4
# Win rate                                             0.773225
# Loss rate                                           -0.738171
# Games Played                                         0.338046
# Average Goals                                        0.534592
# Average Headed goals                                 0.203382
# Average Penalties scored                             0.268370
# Average Freekicks scored                             0.159749
# Average Assists                                      0.491676
# Average Shots                                        0.466338
# Average Shots on target                              0.511832
# Average Hit woodworks                                0.245639
# Average Big chances missed                           0.348838
# Average Passes                                       0.463413
# Average Big chances created                          0.433505
# Average Yellow cards                                -0.003429
# Average Red cards                                   -0.006062
# Average Fouls                                        0.045983
# Average Offsides                                     0.080200
# avg_points                                           0.777468
# pred_top4                                            1.000000

# %%
data_gk=pd.read_csv("avgGKStats.csv")
data_gk_clean=build_data(data_gk)
corr_gk=get_correlation(data_gk_clean)
corr_matrix_gk=data_gk_clean.corr(numeric_only=True)
sns.heatmap(corr_matrix_gk, annot=True, cmap='coolwarm', fmt='.1f')
corr_gk
# Out:
#                                   Correlation with Points Gained  \
# Win rate                                                0.989166
# Loss rate                                              -0.952431
# Games Played                                            0.296191
# Average Saves                                          -0.649598
# Average Penalties saved                                -0.016757
# Average Clean sheets                                    0.900136
# Average Goals conceded                                 -0.851060
# Average Errors leading to a goal                        0.075088
# Average Passes                                         -0.075139
# Average Accurate long balls                            -0.434242
# Average Yellow cards                                    0.164825
# Average Red cards                                       0.205011
# Average Fouls                                           0.097957
# avg_points                                              1.000000
# pred_top4                                               0.802464
#
#                                   Correlation with Predicted Top 4
# Win rate                                                  0.790291
# Loss rate                                                -0.771514
# Games Played                                              0.272572
# Average Saves                                            -0.623820
# Average Penalties saved                                  -0.021091
# Average Clean sheets                                      0.702380
# Average Goals conceded                                   -0.656478
# Average Errors leading to a goal                          0.001488
# Average Passes                                           -0.164367
# Average Accurate long balls                              -0.446233
# Average Yellow cards                                     -0.106881
# Average Red cards                                        -0.025151
# Average Fouls                                             0.103368
# avg_points                                                0.802464
# pred_top4                                                 1.000000

# %%
#NOTE ON AVERAGE SAVES: GOOD EXAMPLE OF CORRELATION BUT NOT CAUSATION BECAUSE OF COURSE SAVING A GOAL DOES NOT AFFECT
#NEGATIVELY THE CHANCES OF A TEAM OF MAKING TOP 4 BUT STRONGER TEAMS HAVE BETTER DEFENCE AND THEY CONCEDE LESS SHOTS. 
#P-VALUE ANALYSIS

# %%
def pvalue_analysis(data):
    stat = []
    p_values = []
    columns = [col for col in data.columns if col not in ['Name', 'Win rate', 'Loss rate', 'Team', 'avg_points', 'pred_top4']]
    for col in columns:
        top4 = data[data['pred_top4'] == 1][col].array
        non_top4 = data[data['pred_top4'] == 0][col].array
        p = stats.ttest_ind(a=top4, b=non_top4, equal_var=True).pvalue
        stat.append(col)
        p_values.append(p)

    d = {'stats':stat,'p-value':p_values}
    p_values = pd.DataFrame(d).sort_values('p-value')

    desirable_stats = p_values[p_values['p-value']<0.05]
    sig_diff_features = desirable_stats['stats'].to_list()

    return desirable_stats

# %%
desirable_stats_def=pvalue_analysis(data_def_clean)
desirable_stats_def
# Out:
#                           stats                p-value
# 10               Average Passes 4.4036067657678774e-08
# 8            Average Duels lost   0.001438838124437852
# 7             Average Duels won    0.01263738526704456
# 12         Average Yellow cards   0.015853562879250698
# 4         Average Interceptions    0.01769592355385208
# 11  Average Accurate long balls    0.02199157431670139
# 14                Average Fouls    0.02603916389347327

# %%
desirable_stats_mid=pvalue_analysis(data_mid_clean)
desirable_stats_mid
# Out:
#                          stats               p-value
# 6               Average Passes 9.617196570970946e-10
# 3              Average Assists 0.0008013749195255877
# 1                Average Goals  0.004965654309920151
# 7  Average Big chances created  0.016543779760162584
# 0                 Games Played  0.019719315845555332

# %%
desirable_stats_fwd=pvalue_analysis(data_fwd_clean)
desirable_stats_fwd
# Out:
#                           stats                p-value
# 1                 Average Goals  9.287319497852202e-07
# 7       Average Shots on target 3.1480123157928437e-06
# 5               Average Assists  8.642044348088708e-06
# 6                 Average Shots 2.8184775630483966e-05
# 10               Average Passes  3.211502015887426e-05
# 11  Average Big chances created 0.00011421164476701145
# 9    Average Big chances missed   0.002318859579150915
# 0                  Games Played  0.0032220383268582275
# 3      Average Penalties scored   0.020784083499431664
# 8         Average Hit woodworks   0.034898723586799574

# %%
desirable_stats_gk=pvalue_analysis(data_gk_clean)
desirable_stats_gk
# Out:
#                          stats                p-value
# 3         Average Clean sheets  2.562843792587906e-06
# 4       Average Goals conceded 1.8486145246914508e-05
# 1                Average Saves  6.229900338398291e-05
# 7  Average Accurate long balls    0.00721161891681924
